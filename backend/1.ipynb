# %%
# !pip install passlib
# Out:
# ...
#   Obtaining dependency information for passlib from https://files.pythonhosted.org/packages/3b/a4/ab6b7589382ca3df236e03faa71deac88cae040af60c071a78d254a62172/passlib-1.7.4-py2.py3-none-any.whl.metadata
#   Using cached passlib-1.7.4-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached passlib-1.7.4-py2.py3-none-any.whl (525 kB)
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from passlib.context import CryptContext
pwd_context = CryptContext(schemes=['pbkdf2_sha256'])
print(pwd_context.hash('Admin@123456'))
# Out:
# $pbkdf2-sha256$29000$g1AqhRBiTKk1JkSIEaIUgg$hWtmt.QMOhmnu3jsu4grIEEX8daOGOLImCGnQCSWIB0

# %%
INSERT INTO users (username, email, hashed_password, first_name, last_name, department, is_active, is_temp_password)
VALUES ('admin', 'admin@pharma-dms.com', '$pbkdf2-sha256$29000$g1AqhRBiTKk1JkSIEaIUgg$hWtmt.QMOhmnu3jsu4grIEEX8daOGOLImCGnQCSWIB0', 'System', 'Administrator', 'IT', TRUE, FALSE);
INSERT INTO user_roles (user_id, role_id)
SELECT u.id, r.id
FROM users u, roles r
WHERE u.username = 'admin' AND r.name = 'DMS_Admin';
